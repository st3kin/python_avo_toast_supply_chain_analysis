# %%
import pandas as pd

avocado = pd.read_csv("CSV_files/avocado.csv", sep = '\t')

relevant_columns = ['code', 'lc', 'product_name_en', 'quantity', 'serving_size', 'packaging_tags', 'brands', 'brands_tags', 'categories_tags', 'labels_tags', 'countries', 'countries_tags', 'origins','origins_tags']

avocado = avocado[relevant_columns]

# Fixing country names in avocado

avocado['origins'] = avocado['origins'].astype('category')
update_avo_origins = {
    'Pérou': 'Peru',
    'Südafrika': 'South Africa',
    'Europäische Union': 'European Union',
    'Dienvidāfrika': 'South Africa',
    'Norwegen': 'Norway',
    'Spania': 'Spain',
    'United States, California': 'United States',
    'Kolumbien': 'Colombia',
    'en:Mexique': 'Mexico',
    'Kenia, Peru': 'Mix',
    'Israel': 'Palestine',
    'Perù': 'Peru',
    'Spānija': 'Spain',
    'en:Espagne': 'Spain',
    'Kenia': 'Kenya',
    'Spanien': 'Spain',
    'Chile, Peru': 'Mix',
    'Simbabwe': 'Zimbabwe',
    'États-Unis': 'United States',
    'Spain, Peru': 'Mix',
    'Dairy from the United States': 'United States',
    'Mexique': 'Mexico',
    'México': 'Mexico'
}

avocado['origins'] = avocado['origins'].replace(update_avo_origins)
avocado['origins'] = avocado['origins'].astype('category')

# Fixing country names in olive oil

olive_oil = pd.read_csv("CSV_files/olive_oil.csv", sep = '\t')

relevant_columns = ['code', 'lc', 'product_name_en', 'quantity', 'serving_size', 'packaging_tags', 'brands', 'brands_tags', 'categories_tags', 'labels_tags', 'countries', 'countries_tags', 'origins','origins_tags']

olive_oil = olive_oil[relevant_columns]

pd.set_option("display.max_rows", None)

olive_oil['origins'] = olive_oil['origins'].astype('category')
update_oo_origins = {
    'Italia': 'Italy',
    'Union européenne': 'European Union',
    'Espagne': 'Spain',
    'Unione europea': 'European Union',
    'España': 'Spain',
    'Italie': 'Italy',
    'Tunisie': 'Tunisia',
    'Griechenland': 'Greece',
    'Grèce': 'Greece',
    'Grèce, Crète': 'Greece',
    'Spanien': 'Spain',
    'Maroc': 'Morocco',
    'Océan Atlantique': 'Atlantic Ocean',
    'Grèce, en:Crete, en:Kolymbari': 'Greece',
    'Grèce, en:Crete': 'Greece',
    'Oceano Pacifico': 'Pacific Ocean',
    'Spain, Greece, Italy, Tunisia': 'Mix',
    'Espagne, Tunisie': 'Spain',
    'Spania': 'Spain',
    'Italien': 'Italy',
    'Tunesien': 'Tunisia',
    'Union Européenne et Non Union Européenne': 'European Union',
    'Greece, Italy, Spain': 'Mix',
    'Greece, Italy, Portugal, Spain, Tunisia': 'Mix',
    'Océan Atlantique, Océan Atlantique Nord-Est': 'Atlantic Ocean',
    'Union Européenne': 'European Union',
    'Spain, Greece, Italy, Portugal, Tunisia': 'Mix',
    'Grčka': 'Greece',
    'Europa': 'European Union',
    'Tbilisi Georgia': 'Georgia',
    'en:aceite de oliva de españa': 'Spain',
    'México': 'Mexico',
    'Turquía': 'Turkey',
    'España, Jaén, Sierra de Cazorla': 'Spain',
    'Španělsko': 'Spain',
    'Union Européenne et Non Union Européenne, Tunisie': 'European Union',
    'Algérie': 'Algeria',
    'Olive oils of European Union origin': 'European Union',
    'Италија': 'Italy',
    'Pologne': 'Poland',
    'Pacific Ocean, West Central Pacific Ocean': 'Pacific Ocean',
    'Southwest Atlantic': 'Atlantic Ocean',
    'Barcelona': 'Spain',
    'Grecja': 'Greece',
    'Unió Europea': 'European Union',
    'Madrid -cádiz km 550.641703 hermanas ( Séville)': 'Spain',
    'Greece, Crete, Kolymbari': 'Greece',
    'Španielsko': 'Spain',
    'en:olive oil from Spain': 'Spain',
    'Greece, Italy, Spain, Tunisia': 'Mix',
    'Produced in Italy': 'Italy',
    'Włochy': 'Italy',
    'Croatia, Istria': 'Croatia',
    'Spanje': 'Spain',
    'Argentina, Chile, Greece, Italy, Peru, Portugal, Morroco, Tunesia': 'Mix',
    'Grèce, Italie, Espagne': 'Mix',
    'Hrvatska': 'Croatia',
    'Italy, Tunisia': 'Mix',
    'United States, California': 'United States',
    'Spain, United States, Argentina, Chile, Greece, Italy, Morocco, Portugal, Tunisia, Turkey': 'Mix',
    'Pérou': 'Peru',
    'en:Grèce': 'Greece',
    'Amerikai Egyesült Államok, Kalifornia': 'United States',
    'Itália': 'Italy',
    'Evropská unie': 'European Union',
    'Oceano Pacifico, FAO 71': 'Pacific Ocean',
    'Griechenland, Kreta': 'Greece',
    'MARRUECOS': 'Morocco',
    'Espagne, Italie, Tunisie': 'Mix',
    'Océan Indien': 'Indian Ocean',
    'en:Griechenland': 'Greece',
    'Europeiska unionen': 'European Union',
    'Greece, fr:Crète': 'Greece',
    'Spagna': 'Spain',
    'Greece, Portugal, Spain': 'Mix',
    'Espagne, es:Bateau : Galerien': 'Spain',
    'en:Włochy': 'Italy',
    'Spanien, Sevilla': 'Spain',
    'Europe': 'European Union',
    "France, Portugal, Spain, fr:Huile d'olive d'Espagne": 'Mix',
    "Côte d'Ivoire": 'Ivory Coast',
    'Italy, fr:Spoleto': 'Italy',
    'Zone FAO 27, Usine portugal': 'Portugal',
    'Argentina, Italy, Peru, Spain': 'Mix',
    'European Union and Non European Union': 'Mix',
    'Croatie': 'Croatia',
    'Beaucaire': 'France',
    'pt:Portugalia': 'Portugal',
    'Grèce, en:Chania': 'Greece',
    'en:Spain': 'Spain',
    'Jaén': 'Spain',
    'Argentina, La Rioja': 'Argentina',
    'pt:Origem: Portugal': 'Portugal',
    'Crète': 'Greece',
    'France, Belgique, Allemagne': 'Mix',
    'France, Portugal, Espagne': 'Mix',
    'Europäische Union': 'European Union',
    'Sardine from Morocco': 'Morocco',
    'en:maqueraux Atlantique Nord-est': 'Atlantic Ocean',
    'Olive oil from Tunisia': 'Tunisia',
    'Испания': 'Spain',
    'Оливковое масло из Греции': 'Greece',
    'Produce of Italy': 'Italy',
    'Grekland': 'Greece',
    'Spain, Tunisia': 'Mix',
    'en:Atlantic Ocean, FAO 34': 'Atlantic Ocean',
    'Olive oil, Organic flour, Organic sourdough starter, Pink Himalayan salt, Rosemary': 'NaN',
    'Gluten free oats, Coconut chips (11%), Dates, Olive oil, Sea salt': 'NaN',
    'Bassin méditerranéen': 'Mediterranean Sea',
    'fr:FAO 37': 'NaN',
    'Fao A P I': 'NaN',
    'Olive': 'NaN',
    'Olives': 'NaN'
}

olive_oil['origins'] = olive_oil['origins'].replace(update_oo_origins)
olive_oil['origins'] = olive_oil['origins'].astype('category')

# Fixing country names in sourdough

sourdough = pd.read_csv("CSV_files/sourdough.csv", sep = '\t')

relevant_columns = ['code', 'lc', 'product_name_en', 'quantity', 'serving_size', 'packaging_tags', 'brands', 'brands_tags', 'categories_tags', 'labels_tags', 'countries', 'countries_tags', 'origins','origins_tags']

sourdough = sourdough[relevant_columns]
pd.set_option("display.max_rows", None)

sourdough['origins'] = sourdough['origins'].astype('category')

update_sourdough_origins = {
    '93% Australian': 'Australia',
    '93% Australian ingredients': 'Australia',
    'Olive oil, Organic flour, Organic sourdough starter, Pink Himalayan salt, Rosemary': 'NaN',
    'de:Meersalz (EU), de:Mohnsamen (EU und Nicht-EU)': 'Mix',
    'Ελλάδα': 'Greece'
}

sourdough['origins'] = sourdough['origins'].replace(update_sourdough_origins)
sourdough['origins'] = sourdough['origins'].astype('category')


def read_and_filter_data(df, colname, top_n=1):
    '''Reads through the file, counts the countries of origin, and returns the top n rows'''
    
    origin_count = {}

    col = df[colname].dropna()
    
    for entry in col:
        if entry in origin_count.keys():
            origin_count[entry] += 1
        else:
            origin_count[entry] = 1

    sorted_origin = dict(sorted(origin_count.items(), key=lambda x: x[1], reverse=True))
    result_df = pd.DataFrame(list(sorted_origin.items()), columns=['origin', 'count'])
    
    return result_df.head(top_n)

avocado_df = read_and_filter_data(avocado, 'origins', top_n=1) 
print(avocado_df)

olive_oil_df = read_and_filter_data(olive_oil, 'origins', top_n=2)
print(olive_oil_df)

sourdough_df = read_and_filter_data(sourdough, 'origins', top_n=1)
print(sourdough_df)

# Results
top_avocado_origin = 'Peru'
top_olive_oil_origin = 'Spain'
top_sourdough_origin = 'United Kingdom'
